# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# ## Importing libraries

# %%
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ---

# %% [markdown]
# ## Reading data as CSV

# %%
df=pd.read_csv('/content/Agrofood_co2_emission.csv')

# %% [markdown]
# ---

# %% [markdown]
# ## Basic data description

# %%
df.head()
# Out:
#           Area  Year  Savanna fires  Forest fires  Crop Residues  \
# 0  Afghanistan  1990        14.7237        0.0557       205.6077
# 1  Afghanistan  1991        14.7237        0.0557       209.4971
# 2  Afghanistan  1992        14.7237        0.0557       196.5341
# 3  Afghanistan  1993        14.7237        0.0557       230.8175
# 4  Afghanistan  1994        14.7237        0.0557       242.0494
#
#    Rice Cultivation  Drained organic soils (CO2)  Pesticides Manufacturing  \
# 0            686.00                          0.0                 11.807483
# 1            678.16                          0.0                 11.712073
# 2            686.00                          0.0                 11.712073
# 3            686.00                          0.0                 11.712073
# 4            705.60                          0.0                 11.712073
#
#    Food Transport  Forestland  ...  Manure Management  Fires in organic soils  \
# ...

# %% [markdown]
# ---

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6965 entries, 0 to 6964
# Data columns (total 31 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Area                             6965 non-null   object
#  1   Year                             6965 non-null   int64
#  2   Savanna fires                    6934 non-null   float64
#  3   Forest fires                     6872 non-null   float64
#  4   Crop Residues                    5576 non-null   float64
#  5   Rice Cultivation                 6965 non-null   float64
#  6   Drained organic soils (CO2)      6965 non-null   float64
#  7   Pesticides Manufacturing         6965 non-null   float64
#  8   Food Transport                   6965 non-null   float64
#  9   Forestland                       6472 non-null   float64
#  10  Net Forest conversion            6472 non-null   float64
# ...

# %% [markdown]
# Here we noticed that in some particular fields there are a lot of NA values. While processing the data we must take in to consideration whether to impute the values or to drop the NA values.

# %% [markdown]
# ---

# %%
df.describe().T
# Out:
#                                   count          mean           std  \
# Year                             6965.0  2.005125e+03  8.894665e+00
# Savanna fires                    6934.0  1.188391e+03  5.246288e+03
# Forest fires                     6872.0  9.193022e+02  3.720079e+03
# Crop Residues                    5576.0  9.987063e+02  3.700345e+03
# Rice Cultivation                 6965.0  4.259667e+03  1.761383e+04
# Drained organic soils (CO2)      6965.0  3.503229e+03  1.586145e+04
# Pesticides Manufacturing         6965.0  3.334184e+02  1.429159e+03
# Food Transport                   6965.0  1.939582e+03  5.616749e+03
# Forestland                       6472.0 -1.782829e+04  8.183221e+04
# Net Forest conversion            6472.0  1.760564e+04  1.011575e+05
# Food Household Consumption       6492.0  4.847580e+03  2.578914e+04
# Food Retail                      6965.0  2.043211e+03  8.494249e+03
# On-farm Electricity Use          6965.0  1.626681e+03  9.343182e+03
# ...

# %% [markdown]
# ---

# %% [markdown]
# # Visualization and Plotting

# %% [markdown]
# ##Correlation Heatmap

# %%
plt.figure(figsize=(12,12))
sns.heatmap(df.corr(),annot=True,fmt="1.1f")
# Out:
# <Axes: >

# %% [markdown]
# We have observed from the heatmap that **forestland has a negative correlation**, which has proven to be an important factor, case in point Bulgaria. Also, Savanna fires, forest fires, Fires in organic soils and Fires in humid tropical forests don't have a significant correlation.

# %% [markdown]
# ---

# %% [markdown]
# ## Total Emission by years

# %%
df.groupby('Year')['total_emission'].sum().plot()
# Out:
# <Axes: xlabel='Year'>

# %% [markdown]
# The graph depicts the growing trend of CO2 emission all over the globe.

# %% [markdown]
# ---

# %% [markdown]
# ## Top 10 Countries by most total emission

# %%
df.groupby('Area')['total_emission'].sum().sort_values(ascending=False).head(10).plot.bar()
# Out:
# <Axes: xlabel='Area'>

# %% [markdown]
# Here we plot the countries with the **highest** total emissions from 1990 to 2020.

# %% [markdown]
# ---

# %% [markdown]
# ## Top 10 Countries by least total emission

# %%
df.groupby('Area')['total_emission'].sum().sort_values(ascending=True).head(10).plot.bar()
# Out:
# <Axes: xlabel='Area'>

# %% [markdown]
# Here we plot the countries with the **lowest** total emissions from 1990 to 2020.

# %% [markdown]
# ---
